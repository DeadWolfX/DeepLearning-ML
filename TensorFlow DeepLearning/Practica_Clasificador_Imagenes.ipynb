# %% [markdown]
# ## Image classifier for the SVHN dataset

# %%
import tensorflow as tf
import numpy as np
from scipy.io import loadmat
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Conv2D , MaxPooling2D , Dense , BatchNormalization , Dropout ,Flatten
from tensorflow.keras import Sequential
import pandas as pd
# %matplotlib inline

# %% [markdown]
# ![SVHN overview image](data/svhn_examples.jpg)
# For the capstone project, you will use the [SVHN dataset](http://ufldl.stanford.edu/housenumbers/). This is an  image dataset of over 600,000 digit images in all, and is a harder dataset than MNIST as the numbers appear in the context of natural scene images. SVHN is obtained from house numbers in Google Street View images.
#
# * Y. Netzer, T. Wang, A. Coates, A. Bissacco, B. Wu and A. Y. Ng. "Reading Digits in Natural Images with Unsupervised Feature Learning". NIPS Workshop on Deep Learning and Unsupervised Feature Learning, 2011.

# %%
# load the dataset

train = loadmat('data/train_32x32.mat')
test = loadmat('data/test_32x32.mat')

# %% [markdown]
# ## 1. Inspect and preprocess the dataset

# %%
#loading training data
X_train = train['X']
y_train = train['y']
#loading test data
X_test = test['X']
y_test = test['y']
#Converting array of shape (32,32,3,Batch) into shape (Batch,32,32,3)
X_train = np.moveaxis(X_train,-1,0)
X_test = np.moveaxis(X_test,-1,0)

# %%
#One-hot encoding y labels
from sklearn.preprocessing import OneHotEncoder

enc = OneHotEncoder().fit(y_train.reshape(-1, 1))

y_train_oh = enc.transform(y_train.reshape(-1, 1)).toarray()
y_test_oh = enc.transform(y_test.reshape(-1, 1)).toarray()

# %%
#Convert images to grayscale and normalize
X_train_gr = np.mean(X_train,3).reshape(73257,32,32,1)/255
X_test_gr = np.mean(X_test,3).reshape(26032, 32, 32,1)/255

# %%
#Show random images
plt.figure(figsize=(10,10))

for i, (image) in enumerate(X_train_gr.take(10)):
    imagen = imagen.numpy().reshape((28,28))
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(imagen, cmap=plt.cm.binary)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-626e37b13278> in <module>
#       2 plt.figure(figsize=(10,10))
#       3
# ----> 4 for i, (image) in enumerate(X_train_gr.take(10)):
#       5     imagen = imagen.numpy().reshape((28,28))
#       6     plt.subplot(5,5,i+1)
#
# TypeError: 'numpy.float64' object is not iterable

# %% [markdown]
# ## 2. MLP neural network classifier

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, BatchNormalization, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
def get_mlp_model(input_shape):
    model = Sequential([
        Flatten(input_shape = input_shape, name = 'flatten_1'),
        Dense((256), activation = 'relu', kernel_initializer='he_uniform', name = 'dense_1'),
        Dense((64), activation = 'relu',  name = 'dense_2'),
        Dense((32), activation = 'relu',  name = 'dense_3'),
        Dense((16), activation = 'relu',  name = 'dense_4'),
        Dense((10), activation = 'softmax', name = 'softmax'),
    ])
    
    model.compile(optimizer = 'adam',
                  loss = 'categorical_crossentropy',
                  metrics = ['accuracy']
    )
    
    return model

# %%
def get_test_accuracy(model, x_test, y_test):
    """Test model classification accuracy"""
    test_loss, test_acc = model.evaluate(x=x_test, y=y_test, verbose=0)
    print('accuracy: {acc:0.3f}'.format(acc=test_acc))

# %%
model_mlp = get_mlp_model(X_train_gr[0].shape)
model_mlp.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               262400
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                16448
# _________________________________________________________________
# dense_3 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_4 (Dense)              (None, 16)                528
# _________________________________________________________________
# softmax (Dense)              (None, 10)                170
# =================================================================
# Total params: 281,626
# Trainable params: 281,626
# Non-trainable params: 0
# _________________________________________________________________

# %%
checkpoint_path_best_mlp = "checkpoints_best_only_mlp/checkpoint"
checkpoint_mlp = ModelCheckpoint(filepath = checkpoint_path_best_mlp,
                                save_weights_only=True,
                                save_best_only=True,
                                save_freq='epoch',
                                monitor = 'val_accuracy',
                                verbose = 1)

early_stopping = EarlyStopping(monitor = 'val_accuracy',
                                  patience=3, verbose=1)

callbacks = [checkpoint_mlp, early_stopping]

history_mlp = model_mlp.fit(X_train_gr, y_train_oh, epochs=30, batch_size=None, validation_split=0.15, callbacks=callbacks, verbose = 1)
# Out:
# Train on 62268 samples, validate on 10989 samples
# Epoch 1/30
# 62144/62268 [============================>.] - ETA: 0s - loss: 2.2063 - accuracy: 0.2012
# Epoch 00001: val_accuracy improved from -inf to 0.25644, saving model to checkpoints_best_only_mlp/checkpoint
# 62268/62268 [==============================] - 55s 885us/sample - loss: 2.2059 - accuracy: 0.2012 - val_loss: 2.0785 - val_accuracy: 0.2564
# Epoch 2/30
# 62144/62268 [============================>.] - ETA: 0s - loss: 1.9996 - accuracy: 0.2934
# Epoch 00002: val_accuracy improved from 0.25644 to 0.36182, saving model to checkpoints_best_only_mlp/checkpoint
# 62268/62268 [==============================] - 45s 716us/sample - loss: 1.9991 - accuracy: 0.2936 - val_loss: 1.8418 - val_accuracy: 0.3618
# Epoch 3/30
# 62112/62268 [============================>.] - ETA: 0s - loss: 1.6876 - accuracy: 0.4120
# Epoch 00003: val_accuracy improved from 0.36182 to 0.44108, saving model to checkpoints_best_only_mlp/checkpoint
# 62268/62268 [==============================] - 45s 716us/sample - loss: 1.6876 - accuracy: 0.4120 - val_loss: 1.5960 - val_accuracy: 0.4411
# Epoch 4/30
# 62208/62268 [============================>.] - ETA: 0s - loss: 1.4907 - accuracy: 0.4845
# Epoch 00004: val_accuracy improved from 0.44108 to 0.51788, saving model to checkpoints_best_only_mlp/checkpoint
# 62268/62268 [==============================] - 45s 729us/sample - loss: 1.4907 - accuracy: 0.4845 - val_loss: 1.4178 - val_accuracy: 0.5179
# Epoch 5/30
# 62240/62268 [============================>.] - ETA: 0s - loss: 1.3663 - accuracy: 0.5434
# Epoch 00005: val_accuracy improved from 0.51788 to 0.56684, saving model to checkpoints_best_only_mlp/checkpoint
# 62268/62268 [==============================] - 47s 753us/sample - loss: 1.3662 - accuracy: 0.5434 - val_loss: 1.3208 - val_accuracy: 0.5668
# Epoch 6/30
# 62144/62268 [============================>.] - ETA: 0s - loss: 1.2631 - accuracy: 0.5914
# Epoch 00006: val_accuracy improved from 0.56684 to 0.59378, saving model to checkpoints_best_only_mlp/checkpoint
# 62268/62268 [==============================] - 53s 854us/sample - loss: 1.2632 - accuracy: 0.5913 - val_loss: 1.2478 - val_accuracy: 0.5938
# Epoch 7/30
# 62144/62268 [============================>.] - ETA: 0s - loss: 1.1888 - accuracy: 0.6189
# Epoch 00007: val_accuracy improved from 0.59378 to 0.59723, saving model to checkpoints_best_only_mlp/checkpoint
# 62268/62268 [==============================] - 53s 853us/sample - loss: 1.1886 - accuracy: 0.6190 - val_loss: 1.2567 - val_accuracy: 0.5972
# Epoch 8/30
# 62208/62268 [============================>.] - ETA: 0s - loss: 1.1389 - accuracy: 0.6391
# Epoch 00008: val_accuracy improved from 0.59723 to 0.63454, saving model to checkpoints_best_only_mlp/checkpoint
# 62268/62268 [==============================] - 53s 851us/sample - loss: 1.1387 - accuracy: 0.6393 - val_loss: 1.1312 - val_accuracy: 0.6345
# Epoch 9/30
# 62208/62268 [============================>.] - ETA: 0s - loss: 1.1037 - accuracy: 0.6516 - ETA: 0s - loss: 1.1058
# Epoch 00009: val_accuracy improved from 0.63454 to 0.64874, saving model to checkpoints_best_only_mlp/checkpoint
# 62268/62268 [==============================] - 53s 846us/sample - loss: 1.1036 - accuracy: 0.6516 - val_loss: 1.1136 - val_accuracy: 0.6487
# Epoch 10/30
# 62176/62268 [============================>.] - ETA: 0s - loss: 1.0647 - accuracy: 0.6659
# Epoch 00010: val_accuracy did not improve from 0.64874
# 62268/62268 [==============================] - 51s 826us/sample - loss: 1.0644 - accuracy: 0.6659 - val_loss: 1.1021 - val_accuracy: 0.6460
# Epoch 11/30
# 62208/62268 [============================>.] - ETA: 0s - loss: 1.0295 - accuracy: 0.6770
# Epoch 00011: val_accuracy improved from 0.64874 to 0.68341, saving model to checkpoints_best_only_mlp/checkpoint
# 62268/62268 [==============================] - 52s 834us/sample - loss: 1.0294 - accuracy: 0.6770 - val_loss: 1.0089 - val_accuracy: 0.6834
# Epoch 12/30
# 62176/62268 [============================>.] - ETA: 0s - loss: 1.0060 - accuracy: 0.6863
# Epoch 00012: val_accuracy improved from 0.68341 to 0.68832, saving model to checkpoints_best_only_mlp/checkpoint
# 62268/62268 [==============================] - 52s 832us/sample - loss: 1.0058 - accuracy: 0.6863 - val_loss: 0.9820 - val_accuracy: 0.6883
# Epoch 13/30
# 62144/62268 [============================>.] - ETA: 0s - loss: 0.9766 - accuracy: 0.6961
# Epoch 00013: val_accuracy improved from 0.68832 to 0.69524, saving model to checkpoints_best_only_mlp/checkpoint
# 62268/62268 [==============================] - 52s 829us/sample - loss: 0.9764 - accuracy: 0.6962 - val_loss: 0.9732 - val_accuracy: 0.6952
# Epoch 14/30
# 62240/62268 [============================>.] - ETA: 0s - loss: 0.9548 - accuracy: 0.7013 ETA
# Epoch 00014: val_accuracy improved from 0.69524 to 0.70625, saving model to checkpoints_best_only_mlp/checkpoint
# 62268/62268 [==============================] - 52s 832us/sample - loss: 0.9548 - accuracy: 0.7013 - val_loss: 0.9392 - val_accuracy: 0.7063
# Epoch 15/30
# 62144/62268 [============================>.] - ETA: 0s - loss: 0.9371 - accuracy: 0.7072
# Epoch 00015: val_accuracy did not improve from 0.70625
# 62268/62268 [==============================] - 45s 727us/sample - loss: 0.9369 - accuracy: 0.7073 - val_loss: 0.9558 - val_accuracy: 0.7022
# Epoch 16/30
# 62208/62268 [============================>.] - ETA: 0s - loss: 0.9223 - accuracy: 0.7131
# Epoch 00016: val_accuracy improved from 0.70625 to 0.71162, saving model to checkpoints_best_only_mlp/checkpoint
# 62268/62268 [==============================] - 51s 818us/sample - loss: 0.9225 - accuracy: 0.7130 - val_loss: 0.9200 - val_accuracy: 0.7116
# Epoch 17/30
# 62176/62268 [============================>.] - ETA: 0s - loss: 0.9031 - accuracy: 0.7192
# Epoch 00017: val_accuracy did not improve from 0.71162
# 62268/62268 [==============================] - 53s 857us/sample - loss: 0.9033 - accuracy: 0.7192 - val_loss: 0.9675 - val_accuracy: 0.6921
# Epoch 18/30
# 62176/62268 [============================>.] - ETA: 0s - loss: 0.8870 - accuracy: 0.7234
# Epoch 00018: val_accuracy improved from 0.71162 to 0.71826, saving model to checkpoints_best_only_mlp/checkpoint
# 62268/62268 [==============================] - 53s 855us/sample - loss: 0.8869 - accuracy: 0.7235 - val_loss: 0.9044 - val_accuracy: 0.7183
# Epoch 19/30
# 62208/62268 [============================>.] - ETA: 0s - loss: 0.8723 - accuracy: 0.7277
# Epoch 00019: val_accuracy improved from 0.71826 to 0.72008, saving model to checkpoints_best_only_mlp/checkpoint
# 62268/62268 [==============================] - 54s 869us/sample - loss: 0.8722 - accuracy: 0.7278 - val_loss: 0.9089 - val_accuracy: 0.7201
# Epoch 20/30
# 62240/62268 [============================>.] - ETA: 0s - loss: 0.8585 - accuracy: 0.7327
# Epoch 00020: val_accuracy did not improve from 0.72008
# 62268/62268 [==============================] - 54s 865us/sample - loss: 0.8585 - accuracy: 0.7327 - val_loss: 0.9064 - val_accuracy: 0.7132
# Epoch 21/30
# 62144/62268 [============================>.] - ETA: 0s - loss: 0.8463 - accuracy: 0.7366 ETA: 1s - los
# Epoch 00021: val_accuracy improved from 0.72008 to 0.73546, saving model to checkpoints_best_only_mlp/checkpoint
# 62268/62268 [==============================] - 54s 870us/sample - loss: 0.8463 - accuracy: 0.7366 - val_loss: 0.8451 - val_accuracy: 0.7355
# Epoch 22/30
# 62240/62268 [============================>.] - ETA: 0s - loss: 0.8364 - accuracy: 0.7395
# Epoch 00022: val_accuracy did not improve from 0.73546
# 62268/62268 [==============================] - 54s 868us/sample - loss: 0.8363 - accuracy: 0.7395 - val_loss: 0.8802 - val_accuracy: 0.7264
# Epoch 23/30
# 62208/62268 [============================>.] - ETA: 0s - loss: 0.8268 - accuracy: 0.7428
# Epoch 00023: val_accuracy did not improve from 0.73546
# 62268/62268 [==============================] - 54s 870us/sample - loss: 0.8267 - accuracy: 0.7428 - val_loss: 0.8727 - val_accuracy: 0.7267
# Epoch 24/30
# 62208/62268 [============================>.] - ETA: 0s - loss: 0.8183 - accuracy: 0.7455
# Epoch 00024: val_accuracy improved from 0.73546 to 0.74356, saving model to checkpoints_best_only_mlp/checkpoint
# 62268/62268 [==============================] - 54s 870us/sample - loss: 0.8186 - accuracy: 0.7455 - val_loss: 0.8241 - val_accuracy: 0.7436
# Epoch 25/30
# 62240/62268 [============================>.] - ETA: 0s - loss: 0.8101 - accuracy: 0.7476
# Epoch 00025: val_accuracy did not improve from 0.74356
# 62268/62268 [==============================] - 53s 849us/sample - loss: 0.8101 - accuracy: 0.7476 - val_loss: 0.8464 - val_accuracy: 0.7345
# Epoch 26/30
# 62240/62268 [============================>.] - ETA: 0s - loss: 0.7959 - accuracy: 0.7528
# Epoch 00026: val_accuracy improved from 0.74356 to 0.74529, saving model to checkpoints_best_only_mlp/checkpoint
# 62268/62268 [==============================] - 53s 845us/sample - loss: 0.7959 - accuracy: 0.7527 - val_loss: 0.8184 - val_accuracy: 0.7453
# Epoch 27/30
# 62208/62268 [============================>.] - ETA: 0s - loss: 0.7892 - accuracy: 0.7557
# Epoch 00027: val_accuracy improved from 0.74529 to 0.75503, saving model to checkpoints_best_only_mlp/checkpoint
# 62268/62268 [==============================] - 52s 835us/sample - loss: 0.7891 - accuracy: 0.7558 - val_loss: 0.7972 - val_accuracy: 0.7550
# Epoch 28/30
# 62144/62268 [============================>.] - ETA: 0s - loss: 0.7829 - accuracy: 0.7560
# Epoch 00028: val_accuracy did not improve from 0.75503
# 62268/62268 [==============================] - 52s 836us/sample - loss: 0.7832 - accuracy: 0.7560 - val_loss: 0.8468 - val_accuracy: 0.7349
# Epoch 29/30
# 62144/62268 [============================>.] - ETA: 0s - loss: 0.7723 - accuracy: 0.7598
# Epoch 00029: val_accuracy did not improve from 0.75503
# 62268/62268 [==============================] - 53s 846us/sample - loss: 0.7725 - accuracy: 0.7597 - val_loss: 0.8083 - val_accuracy: 0.7512
# Epoch 30/30
# 62144/62268 [============================>.] - ETA: 0s - loss: 0.7658 - accuracy: 0.7625
# Epoch 00030: val_accuracy did not improve from 0.75503
# 62268/62268 [==============================] - 45s 729us/sample - loss: 0.7656 - accuracy: 0.7624 - val_loss: 0.8300 - val_accuracy: 0.7467
# Epoch 00030: early stopping

# %%
get_test_accuracy(model_mlp,X_test_gr, y_test_oh)
# Plot the training and validation loss and accuracy

plt.plot(history_mlp.history['loss'])
plt.plot(history_mlp.history['val_loss'])
plt.title('Loss vs. epochs')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.show()

plt.plot(history_mlp.history['accuracy'])
plt.plot(history_mlp.history['val_accuracy'])
plt.title('Accuracy vs. epochs')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.show()
# Out:
# accuracy: 0.710

# %% [markdown]
# ## 3. CNN neural network classifier

# %%
def get_cnn_model(input_shape):
    model = Sequential([
      Conv2D(kernel_size = (3,3), filters = 16, padding = 'SAME', activation = 'relu', input_shape = input_shape, name = 'conv_1', kernel_initializer='he_uniform'),
        MaxPooling2D((2,2), name = 'max_pool_1'),
        BatchNormalization(name = 'batch_norm_1'),
        Conv2D(kernel_size = (3,3), filters = 32, padding = 'SAME', activation = 'relu', name = 'conv_2',  kernel_initializer='he_uniform'),
        MaxPooling2D((2,2), name = 'max_pool_2'),
        BatchNormalization(name = 'batch_norm_2'),
        Flatten(),
        Dense(64, activation = 'relu', name = 'dense_1'),
        Dropout(0.5, name = 'dropout_1'),
        Dense(64, activation = 'relu', name = 'dense_2'),
        Dense(10,activation = 'softmax', name = 'softmax')
    ])
    
    model.compile(optimizer = 'adam',
                  loss = 'categorical_crossentropy',
                  metrics = ['accuracy']
    )
    
    return model

# %%
model_cnn = get_cnn_model(X_train_gr[0].shape)
model_cnn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv_1 (Conv2D)              (None, 32, 32, 16)        160
# _________________________________________________________________
# max_pool_1 (MaxPooling2D)    (None, 16, 16, 16)        0
# _________________________________________________________________
# batch_norm_1 (BatchNormaliza (None, 16, 16, 16)        64
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 16, 16, 32)        4640
# _________________________________________________________________
# max_pool_2 (MaxPooling2D)    (None, 8, 8, 32)          0
# _________________________________________________________________
# batch_norm_2 (BatchNormaliza (None, 8, 8, 32)          128
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                131136
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                4160
# _________________________________________________________________
# softmax (Dense)              (None, 10)                650
# =================================================================
# Total params: 140,938
# Trainable params: 140,842
# Non-trainable params: 96
# _________________________________________________________________

# %%
checkpoint_path_best_cnn = "checkpoints_best_only_cnn/checkpoint"
checkpoint_cnn = ModelCheckpoint(filepath = checkpoint_path_best_cnn,
                                save_weights_only=True,
                                save_best_only=True,
                                save_freq='epoch',
                                monitor = 'val_accuracy',
                                verbose = 1)

# %%
callbacks = [checkpoint_cnn, early_stopping]
history_cnn = model_cnn.fit(X_train_gr, y_train_oh, epochs=30,validation_split=0.15, callbacks=callbacks, verbose = 1)
# Out:
# Train on 62268 samples, validate on 10989 samples
# Epoch 1/30
# 62240/62268 [============================>.] - ETA: 0s - loss: 1.2641 - accuracy: 0.5610
# Epoch 00001: val_accuracy improved from -inf to 0.81764, saving model to checkpoints_best_only_cnn/checkpoint
# 62268/62268 [==============================] - 320s 5ms/sample - loss: 1.2638 - accuracy: 0.5611 - val_loss: 0.6117 - val_accuracy: 0.8176
# Epoch 2/30
# 62240/62268 [============================>.] - ETA: 0s - loss: 0.7013 - accuracy: 0.7763
# Epoch 00002: val_accuracy improved from 0.81764 to 0.84912, saving model to checkpoints_best_only_cnn/checkpoint
# 62268/62268 [==============================] - 305s 5ms/sample - loss: 0.7013 - accuracy: 0.7763 - val_loss: 0.5072 - val_accuracy: 0.8491
# Epoch 3/30
# 62240/62268 [============================>.] - ETA: 0s - loss: 0.5939 - accuracy: 0.8141
# Epoch 00003: val_accuracy did not improve from 0.84912
# 62268/62268 [==============================] - 301s 5ms/sample - loss: 0.5938 - accuracy: 0.8141 - val_loss: 0.4973 - val_accuracy: 0.8488
# Epoch 4/30
# 62240/62268 [============================>.] - ETA: 0s - loss: 0.5409 - accuracy: 0.8304
# Epoch 00004: val_accuracy improved from 0.84912 to 0.87032, saving model to checkpoints_best_only_cnn/checkpoint
# 62268/62268 [==============================] - 301s 5ms/sample - loss: 0.5411 - accuracy: 0.8304 - val_loss: 0.4561 - val_accuracy: 0.8703
# Epoch 5/30
# 62240/62268 [============================>.] - ETA: 0s - loss: 0.4969 - accuracy: 0.8447
# Epoch 00005: val_accuracy did not improve from 0.87032
# 62268/62268 [==============================] - 304s 5ms/sample - loss: 0.4968 - accuracy: 0.8448 - val_loss: 0.4511 - val_accuracy: 0.8678
# Epoch 6/30
# 62240/62268 [============================>.] - ETA: 0s - loss: 0.4668 - accuracy: 0.8547
# Epoch 00006: val_accuracy improved from 0.87032 to 0.87751, saving model to checkpoints_best_only_cnn/checkpoint
# 62268/62268 [==============================] - 302s 5ms/sample - loss: 0.4670 - accuracy: 0.8546 - val_loss: 0.4437 - val_accuracy: 0.8775
# Epoch 7/30
# 62240/62268 [============================>.] - ETA: 0s - loss: 0.4495 - accuracy: 0.8602
# Epoch 00007: val_accuracy did not improve from 0.87751
# 62268/62268 [==============================] - 298s 5ms/sample - loss: 0.4497 - accuracy: 0.8603 - val_loss: 0.4229 - val_accuracy: 0.8773
# Epoch 8/30
# 62240/62268 [============================>.] - ETA: 0s - loss: 0.4307 - accuracy: 0.8650
# Epoch 00008: val_accuracy improved from 0.87751 to 0.88379, saving model to checkpoints_best_only_cnn/checkpoint
# 62268/62268 [==============================] - 300s 5ms/sample - loss: 0.4307 - accuracy: 0.8650 - val_loss: 0.4026 - val_accuracy: 0.8838
# Epoch 9/30
# 62240/62268 [============================>.] - ETA: 0s - loss: 0.4141 - accuracy: 0.8702
# Epoch 00009: val_accuracy did not improve from 0.88379
# 62268/62268 [==============================] - 302s 5ms/sample - loss: 0.4141 - accuracy: 0.8703 - val_loss: 0.4020 - val_accuracy: 0.8781
# Epoch 10/30
# 62240/62268 [============================>.] - ETA: 0s - loss: 0.4033 - accuracy: 0.8728
# Epoch 00010: val_accuracy improved from 0.88379 to 0.88698, saving model to checkpoints_best_only_cnn/checkpoint
# 62268/62268 [==============================] - 299s 5ms/sample - loss: 0.4031 - accuracy: 0.8729 - val_loss: 0.3921 - val_accuracy: 0.8870
# Epoch 11/30
# 62240/62268 [============================>.] - ETA: 0s - loss: 0.3882 - accuracy: 0.8771
# Epoch 00011: val_accuracy improved from 0.88698 to 0.88825, saving model to checkpoints_best_only_cnn/checkpoint
# 62268/62268 [==============================] - 300s 5ms/sample - loss: 0.3882 - accuracy: 0.8771 - val_loss: 0.3918 - val_accuracy: 0.8883
# Epoch 12/30
# 62240/62268 [============================>.] - ETA: 0s - loss: 0.3802 - accuracy: 0.8801
# Epoch 00012: val_accuracy did not improve from 0.88825
# 62268/62268 [==============================] - 298s 5ms/sample - loss: 0.3803 - accuracy: 0.8800 - val_loss: 0.3938 - val_accuracy: 0.8883
# Epoch 13/30
# 62240/62268 [============================>.] - ETA: 0s - loss: 0.3715 - accuracy: 0.8826
# Epoch 00013: val_accuracy did not improve from 0.88825
# 62268/62268 [==============================] - 316s 5ms/sample - loss: 0.3714 - accuracy: 0.8825 - val_loss: 0.3978 - val_accuracy: 0.8822
# Epoch 14/30
# 62240/62268 [============================>.] - ETA: 0s - loss: 0.3593 - accuracy: 0.8877
# Epoch 00014: val_accuracy did not improve from 0.88825
# 62268/62268 [==============================] - 317s 5ms/sample - loss: 0.3593 - accuracy: 0.8877 - val_loss: 0.3955 - val_accuracy: 0.8826
# Epoch 00014: early stopping

# %%
# Plot the training and validation loss and accuracy

plt.plot(history_cnn.history['loss'])
plt.plot(history_cnn.history['val_loss'])
plt.title('Loss vs. epochs')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.show()

plt.plot(history_cnn.history['accuracy'])
plt.plot(history_cnn.history['val_accuracy'])
plt.title('Accuracy vs. epochs')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.show()

# %%
get_test_accuracy(model_cnn,X_test_gr, y_test_oh)
# Out:
# accuracy: 0.874

# %% [markdown]
# ## 4. Get model predictions

# %%
#loading model weights for mlp
model = get_mlp_model(X_train_gr[0].shape)
model.load_weights("/content/checkpoints_best_only_mlp/checkpoint")
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-30-33851ea0612c> in <module>
#       1 #loading model weights for mlp
#       2 model = get_mlp_model(X_train_gr[0].shape)
# ----> 3 model.load_weights("/content/checkpoints_best_only_mlp/checkpoint")
#
# /opt/conda/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training.py in load_weights(self, filepath, by_name)
#     179         raise ValueError('Load weights is not yet supported with TPUStrategy '
#     180                          'with steps_per_run greater than 1.')
# --> 181     return super(Model, self).load_weights(filepath, by_name)
#     182
#     183   @trackable.no_automatic_dependency_tracking
#
# /opt/conda/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/network.py in load_weights(self, filepath, by_name)
#    1141     else:
#    1142       try:
# -> 1143         pywrap_tensorflow.NewCheckpointReader(filepath)
#    1144         save_format = 'tf'
#    1145       except errors_impl.DataLossError:
#
# /opt/conda/lib/python3.7/site-packages/tensorflow_core/python/pywrap_tensorflow_internal.py in NewCheckpointReader(filepattern)
#     871 def NewCheckpointReader(filepattern):
#     872   from tensorflow.python.util import compat
# --> 873   return CheckpointReader(compat.as_bytes(filepattern))
#     874
#     875 NewCheckpointReader._tf_api_names_v1 = ['train.NewCheckpointReader']
#
# /opt/conda/lib/python3.7/site-packages/tensorflow_core/python/pywrap_tensorflow_internal.py in __init__(self, filename)
#     883
#     884     def __init__(self, filename):
# --> 885         this = _pywrap_tensorflow_internal.new_CheckpointReader(filename)
#     886         try:
#     887             self.this.append(this)
#
# InvalidArgumentError: Unsuccessful TensorSliceReader constructor: Failed to get matching files on /content/checkpoints_best_only_mlp/checkpoint: Not found: /content/checkpoints_best_only_mlp; No such file or directory

# %%
print(get_test_accuracy(model,X_test_gr, y_test_oh))
# Out:
# accuracy: 0.101
# None

# %%
num_test_images = X_test_gr.shape[0]

random_inx = np.random.choice(num_test_images, 5)
random_test_images = X_test_gr[random_inx, ...]
random_test_labels = y_test[random_inx, ...]

predictions = model.predict(random_test_images)

fig, axes = plt.subplots(5, 2, figsize=(16, 12))
fig.subplots_adjust(hspace=0.4, wspace=-0.2)

for i, (prediction, image, label) in enumerate(zip(predictions, random_test_images, random_test_labels)):
    axes[i, 0].imshow(np.squeeze(image))
    axes[i, 0].get_xaxis().set_visible(False)
    axes[i, 0].get_yaxis().set_visible(False)
    axes[i, 0].text(10., -1.5, f'Digit {label}')
    axes[i, 1].bar(np.arange(1,11), prediction)
    axes[i, 1].set_xticks(np.arange(1,11))
    axes[i, 1].set_title("Categorical distribution. Model prediction")
    
plt.show()

# %%
#loading model weights for cnn
model = get_cnn_model(X_train_gr[0].shape)
model.load_weights("/content/checkpoints_best_only_cnn/checkpoint")
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-31-8c7309e025c2> in <module>
#       1 #loading model weights for cnn
#       2 model = get_cnn_model(X_train_gr[0].shape)
# ----> 3 model.load_weights("/content/checkpoints_best_only_cnn/checkpoint")
#
# /opt/conda/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training.py in load_weights(self, filepath, by_name)
#     179         raise ValueError('Load weights is not yet supported with TPUStrategy '
#     180                          'with steps_per_run greater than 1.')
# --> 181     return super(Model, self).load_weights(filepath, by_name)
#     182
#     183   @trackable.no_automatic_dependency_tracking
#
# /opt/conda/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/network.py in load_weights(self, filepath, by_name)
#    1141     else:
#    1142       try:
# -> 1143         pywrap_tensorflow.NewCheckpointReader(filepath)
#    1144         save_format = 'tf'
#    1145       except errors_impl.DataLossError:
#
# /opt/conda/lib/python3.7/site-packages/tensorflow_core/python/pywrap_tensorflow_internal.py in NewCheckpointReader(filepattern)
#     871 def NewCheckpointReader(filepattern):
#     872   from tensorflow.python.util import compat
# --> 873   return CheckpointReader(compat.as_bytes(filepattern))
#     874
#     875 NewCheckpointReader._tf_api_names_v1 = ['train.NewCheckpointReader']
#
# /opt/conda/lib/python3.7/site-packages/tensorflow_core/python/pywrap_tensorflow_internal.py in __init__(self, filename)
#     883
#     884     def __init__(self, filename):
# --> 885         this = _pywrap_tensorflow_internal.new_CheckpointReader(filename)
#     886         try:
#     887             self.this.append(this)
#
# InvalidArgumentError: Unsuccessful TensorSliceReader constructor: Failed to get matching files on /content/checkpoints_best_only_cnn/checkpoint: Not found: /content/checkpoints_best_only_cnn; No such file or directory

# %%
print(get_test_accuracy(model,X_test_gr, y_test_oh))
# Out:
# accuracy: 0.109
# None

# %%
num_test_images = X_test_gr.shape[0]

random_inx = np.random.choice(num_test_images, 5)
random_test_images = X_test_gr[random_inx, ...]
random_test_labels = y_test[random_inx, ...]

predictions = model.predict(random_test_images)

fig, axes = plt.subplots(5, 2, figsize=(16, 12))
fig.subplots_adjust(hspace=0.4, wspace=-0.2)

for i, (prediction, image, label) in enumerate(zip(predictions, random_test_images, random_test_labels)):
    axes[i, 0].imshow(np.squeeze(image))
    axes[i, 0].get_xaxis().set_visible(False)
    axes[i, 0].get_yaxis().set_visible(False)
    axes[i, 0].text(10., -1.5, f'Digit {label}')
    axes[i, 1].bar(np.arange(1,11), prediction)
    axes[i, 1].set_xticks(np.arange(1,11))
    axes[i, 1].set_title("Categorical distribution. Model prediction")
    
plt.show()
